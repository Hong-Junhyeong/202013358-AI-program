# %%
#lAB 2-1
print('나의 이름은:','홍준형')
# Out:
# 나의 이름은: 홍준형

# %%
#lAB 2-1
print('나의 나이는:',27)
print('나의 키는', 168, 'cm입니다.')
print('10+20=',10+20)
print('10*20=',10*20)
# Out:
# 나의 나이는: 27
# 나의 키는 168 cm입니다.
# 10+20= 30
# 10*20= 200

# %%
#lAB 2-2
name='홍준형'
print('나의 이름은:',name)
age=27
print('나의 나이는:',age)
height=168
print('나의 키는',height,'cm 입니다.')
sum=10+20
print('10+20=', sum)
mult=10*20
print('10*20=',mult)
# Out:
# 나의 이름은: 홍준형
# 나의 나이는: 27
# 나의 키는 168 cm 입니다.
# 10+20= 30
# 10*20= 200

# %%
#LAB 2-6
width=20
height=40
widit=30
area=width*height
print('사각형의 면적',area)
# Out:
# 사각형의 면적 800

# %%
#LAB 2-7
print(123*456)
print(1357+2468)
print(5**4)
print(10/4)
print(10//5)
print(10%5)

print(5%2)

root2 = 2 ** 0.5
root3 = 3 ** 0.5
print(f"2의 제곱근: {root2}")
print(f"3의 제곱근: {root3}")
# Out:
# 56088
# 3825
# 625
# 2.5
# 2
# 0
# 1
# 2의 제곱근: 1.4142135623730951
# 3의 제곱근: 1.7320508075688772

# %%
#LAB 2-7
a,b=(8+2j, 4+3j)
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# (12+5j)
# (4-1j)
# (26+32j)
# (1.52-0.64j)

# %%
#LAB 2-9
a=1024
print(a>>1)
#1
print(a>>2)
#2
a=a>>1
print(a)
#3
a=a>>1
print(a)
#4
a=1
print(a<<1)
#5
a=a<<1
print(a)
#6
a=a<<1
print(a)
#7
a=a<<1
print(a)
#8
a=a<<1
print(a)
# Out:
# 512
# 256
# 512
# 256
# 2
# 2
# 4
# 8
# 16

# %%
#LAB 2-10
name = input('이름을 입력하세요 : ')
print(name, '님이 입장하셨습니다.')
# Out:
# 이름을 입력하세요 :  홍준형
# 홍준형 님이 입장하셨습니다.

# %%
#LAB 2-10
m = int(input('숫자 m을 입력하세요 : '))
n = int(input('숫자 n을 입력하세요 : '))
print('m+n=', m+n)
print('m-n=', m-n)
# Out:
# 숫자 m을 입력하세요 :  10
# 숫자 n을 입력하세요 :  20
# m+n= 30
# m-n= -10

# %%
#LAB 2-10
r = int(input('원의 r을 입력하세요 : '))
n = 3.14
print('원의 넓이=', n*r*r)
# Out:
# 원의 r을 입력하세요 :  10
# 원의 넓이= 314.0
