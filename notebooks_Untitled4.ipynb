# %%
'''
num = 100
print('num=',num)
'''
# Out:
# num= 100

# %%
'''
num = 200
print('num=',num)
'''
# Out:
# num= 200

# %%
#제어문
num=0
for i in range(3):
    num += 100
    print('num=',num)
# Out:
# num= 100
# num= 200
# num= 300

# %%
'''
#제어문
num=0
for i in range(3):
    num += 100
    print('ith num=', i, num)
'''
# Out:
# ith num= 0 100
# ith num= 1 200
# ith num= 2 300

# %%
age = int(input("나이를 입력하세요:"))

if age < 20:
    print("청소년 할인")
elif age > 65:
    print("경로 우대")
# Out:
# 나이를 입력하세요: 19
# 청소년 할인
